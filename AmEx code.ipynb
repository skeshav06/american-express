# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data= pd.read_csv("OneDrive/Desktop/Data/Book2.csv")
train_data.head()
# Out:
#     cust_id  profitable_flag  count_accts  cm_age  flag_top_ed_spender  \
# 0  550391.0              0.0          1.0    74.0                  1.0
# 1  550392.0              0.0          1.0    64.0                  0.0
# 2  550393.0              0.0          1.0    75.0                  1.0
# 3  550394.0              0.0          2.0    73.0                  0.0
# 4  550395.0              0.0          2.0    68.0                  0.0
#
#    flag_cust_fee_paid_6m  pre6m_cust_spend  pre6m_cust_roc_cnt  \
# 0                    0.0            1518.0               122.0
# 1                    0.0            4807.0               354.0
# 2                    0.0            2361.0               204.0
# 3                    1.0            5452.0               142.0
# 4                    0.0             170.0                34.0
#
#    pre6m_cust_non_disc_amt  pre6m_cust_non_disc_cnt  ...  \
# 0                    811.0                     96.0  ...
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19596 entries, 0 to 19595
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cust_id                         19595 non-null  float64
#  1   profitable_flag                 19595 non-null  float64
#  2   count_accts                     19595 non-null  float64
#  3   cm_age                          19595 non-null  float64
#  4   flag_top_ed_spender             19547 non-null  float64
#  5   flag_cust_fee_paid_6m           19595 non-null  float64
#  6   pre6m_cust_spend                19005 non-null  float64
#  7   pre6m_cust_roc_cnt              19595 non-null  float64
#  8   pre6m_cust_non_disc_amt         18413 non-null  float64
#  9   pre6m_cust_non_disc_cnt         19595 non-null  float64
#  10  pre6m_cust_disc_amt             18902 non-null  float64
#  11  pre6m_cust_disc_cnt             19595 non-null  float64
# ...

# %%
test_data= pd.read_csv("OneDrive/Desktop/Data/test_datset.csv")
test_data.shape
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 49 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cust_id                         5000 non-null   int64
#  1   count_accts                     5000 non-null   int64
#  2   cm_age                          5000 non-null   int64
#  3   flag_top_ed_spender             4985 non-null   float64
#  4   flag_cust_fee_paid_6m           5000 non-null   int64
#  5   pre6m_cust_spend                4823 non-null   float64
#  6   pre6m_cust_roc_cnt              5000 non-null   int64
#  7   pre6m_cust_non_disc_amt         4649 non-null   float64
#  8   pre6m_cust_non_disc_cnt         5000 non-null   int64
#  9   pre6m_cust_disc_amt             4803 non-null   float64
#  10  pre6m_cust_disc_cnt             5000 non-null   int64
#  11  pre6m_cust_outbound_amt         4425 non-null   float64
# ...

# %%
train_data.isnull().sum()
# Out:
# cust_id                               1
# profitable_flag                       1
# count_accts                           1
# cm_age                                1
# flag_top_ed_spender                  49
# flag_cust_fee_paid_6m                 1
# pre6m_cust_spend                    591
# pre6m_cust_roc_cnt                    1
# pre6m_cust_non_disc_amt            1183
# pre6m_cust_non_disc_cnt               1
# pre6m_cust_disc_amt                 694
# pre6m_cust_disc_cnt                   1
# pre6m_cust_outbound_amt            2192
# pre6m_cust_online_amt              1212
# pre6m_cust_online_cnt                 1
# pre6m_cust_travel_amt              1922
# pre6m_cust_travel_cnt                 1
# pre6m_cust_retail_amt               835
# pre6m_cust_retail_cnt                 1
# pre6m_cust_myca_active                1
# pre6m_cust_mob_logins                 1
# pre6m_total_mc_trs                    1
# acq_sub_chn                         903
# ...

# %%
train_data=train_data.drop(['acq_sub_chn'],axis=1)
test_data=test_data.drop(['acq_sub_chn'],axis=1)
test_data=test_data.drop(['acq_type_grp'],axis=1)
train_data=train_data.drop(['acq_type_grp'],axis=1)

# %%
print(train_data.shape, test_data.shape)
# Out:
# (19596, 48) (5000, 47)

# %%
train_data=train_data.drop(['cnsumr_chrg_avg_credit_12m_amt'],axis=1)
test_data=test_data.drop(['cnsumr_chrg_avg_credit_12m_amt'],axis=1)
train_data=train_data.drop(['sow_tot_annual_ext_pmt_amt'],axis=1)
test_data=test_data.drop(['sow_tot_annual_ext_pmt_amt'],axis=1)
train_data=train_data.drop(['sow_tot_revol_bal_amt'],axis=1)
test_data=test_data.drop(['sow_tot_revol_bal_amt'],axis=1)
train_data=train_data.drop(['sow_tot_trans_bal_amt'],axis=1)
test_data=test_data.drop(['sow_tot_trans_bal_amt'],axis=1)

# %%
train_data = train_data.merge(pd.get_dummies(train_data.fee_type_grp, drop_first=True, prefix='fee_type_grp'), left_index=True, right_index=True)
test_data = test_data.merge(pd.get_dummies(train_data.fee_type_grp, drop_first=True, prefix='fee_type_grp'), left_index=True, right_index=True)

# %%
train_data= train_data.drop(['cust_id'],axis=1)
test_data=test_data.drop(['cust_id'],axis=1)

# %%
train_data= train_data.drop(['fee_type_grp'],axis=1)
test_data=test_data.drop(['fee_type_grp'],axis=1)

# %%
plt.figure(figsize=(14,12))
sns.heatmap(train_data.corr(),linewidths=0.1,vmax=1.0, 
            square=True,  linecolor='white', annot=True)
plt.show()

# %%
train_data= train_data.drop(['pre6m_cust_retail_amt'],axis=1)
test_data=test_data.drop(['pre6m_cust_retail_amt'],axis=1)
train_data= train_data.drop(['pre6m_cust_travel_amt'],axis=1)
test_data=test_data.drop(['pre6m_cust_travel_amt'],axis=1)
train_data= train_data.drop(['pre6m_cust_online_amt'],axis=1)
test_data=test_data.drop(['pre6m_cust_online_amt'],axis=1)
train_data= train_data.drop(['pre6m_cust_outbound_amt'],axis=1)
test_data=test_data.drop(['pre6m_cust_outbound_amt'],axis=1)
train_data= train_data.drop(['pre6m_cust_disc_amt'],axis=1)
test_data=test_data.drop(['pre6m_cust_disc_amt'],axis=1)
train_data= train_data.drop(['pre6m_cust_non_disc_amt'],axis=1)
test_data=test_data.drop(['pre6m_cust_non_disc_amt'],axis=1)

# %%
train_data['pre6m_spend_active_ind']=train_data['pre6m_spend_active_ind'].fillna(train_data['pre6m_spend_active_ind'].mode()[0])
test_data['pre6m_spend_active_ind']=test_data['pre6m_spend_active_ind'].fillna(test_data['pre6m_spend_active_ind'].mode()[0])
train_data['highly_utilized_ind']=train_data['highly_utilized_ind'].fillna(train_data['highly_utilized_ind'].mode()[0])
test_data['highly_utilized_ind']=test_data['highly_utilized_ind'].fillna(test_data['highly_utilized_ind'].mode()[0])
train_data['min_pay_ind']=train_data['min_pay_ind'].fillna(train_data['min_pay_ind'].mode()[0])
test_data['min_pay_ind']=test_data['min_pay_ind'].fillna(test_data['min_pay_ind'].mode()[0])
train_data['paid_in_full_ind']=train_data['paid_in_full_ind'].fillna(train_data['paid_in_full_ind'].mode()[0])
test_data['paid_in_full_ind']=test_data['paid_in_full_ind'].fillna(test_data['paid_in_full_ind'].mode()[0])

# %%
train_data['profitable_flag']=train_data['profitable_flag'].fillna(train_data['profitable_flag'].mode()[0])
train_data['count_accts']=train_data['count_accts'].fillna(train_data['count_accts'].mode()[0])
train_data['flag_top_ed_spender']=train_data['flag_top_ed_spender'].fillna(train_data['flag_top_ed_spender'].mode()[0])
train_data['flag_cust_fee_paid_6m']=train_data['flag_cust_fee_paid_6m'].fillna(train_data['flag_cust_fee_paid_6m'].mode()[0])
test_data['flag_top_ed_spender']=test_data['flag_top_ed_spender'].fillna(test_data['flag_top_ed_spender'].mode()[0])
train_data['flag_top_ed_spender']=train_data['flag_top_ed_spender'].fillna(train_data['flag_top_ed_spender'].mode()[0])

# %%
train_data['pre6m_cust_spend']=train_data['pre6m_cust_spend'].fillna(train_data['pre6m_cust_spend'].mean())
test_data['pre6m_cust_spend']=test_data['pre6m_cust_spend'].fillna(test_data['pre6m_cust_spend'].mean())
train_data['Cust_tenure']=train_data['Cust_tenure'].fillna(train_data['Cust_tenure'].mean())
test_data['Cust_tenure']=test_data['Cust_tenure'].fillna(test_data['Cust_tenure'].mean())

# %%
train_data['cm_age']=train_data['cm_age'].fillna(train_data['cm_age'].mean())
train_data['pre6m_cust_roc_cnt']=train_data['pre6m_cust_roc_cnt'].fillna(train_data['pre6m_cust_roc_cnt'].mean())
train_data['pre6m_cust_non_disc_cnt']=train_data['pre6m_cust_non_disc_cnt'].fillna(train_data['pre6m_cust_non_disc_cnt'].mean())
train_data['pre6m_cust_disc_cnt']=train_data['pre6m_cust_disc_cnt'].fillna(train_data['pre6m_cust_disc_cnt'].mean())
train_data['pre6m_cust_online_cnt']=train_data['pre6m_cust_online_cnt'].fillna(train_data['pre6m_cust_online_cnt'].mean())
train_data['pre6m_cust_travel_cnt']=train_data['pre6m_cust_travel_cnt'].fillna(train_data['pre6m_cust_travel_cnt'].mean())
train_data['pre6m_cust_retail_cnt']=train_data['pre6m_cust_retail_cnt'].fillna(train_data['pre6m_cust_retail_cnt'].mean())
train_data['pre6m_cust_myca_active']=train_data['pre6m_cust_myca_active'].fillna(train_data['pre6m_cust_myca_active'].mean())
train_data['pre6m_cust_mob_logins']=train_data['pre6m_cust_mob_logins'].fillna(train_data['pre6m_cust_mob_logins'].mean())
train_data['pre6m_total_mc_trs']=train_data['pre6m_total_mc_trs'].fillna(train_data['pre6m_total_mc_trs'].mean())

# %%
train_data['sum_total_line_amt']=train_data['sum_total_line_amt'].fillna(train_data['sum_total_line_amt'].mean())
test_data['sum_total_line_amt']=test_data['sum_total_line_amt'].fillna(test_data['sum_total_line_amt'].mean())

# %%
test_data['direct_debit_ind']=test_data['direct_debit_ind'].fillna(test_data['direct_debit_ind'].mode()[0])
train_data['direct_debit_ind']=train_data['direct_debit_ind'].fillna(train_data['direct_debit_ind'].mode()[0])
test_data['referrals']=test_data['referrals'].fillna(test_data['referrals'].mode()[0])
train_data['referrals']=train_data['referrals'].fillna(train_data['referrals'].mode()[0])
test_data['spillover']=test_data['spillover'].fillna(test_data['spillover'].mode()[0])
train_data['spillover']=train_data['spillover'].fillna(train_data['spillover'].mode()[0])
test_data['self_accts']=test_data['self_accts'].fillna(test_data['self_accts'].mode()[0])
train_data['self_accts']=train_data['self_accts'].fillna(train_data['self_accts'].mode()[0])

# %%
train_data['CustomerLowQualityindicator']=train_data['CustomerLowQualityindicator'].fillna(train_data['CustomerLowQualityindicator'].mode()[0])
test_data['CustomerLowQualityindicator']=test_data['CustomerLowQualityindicator'].fillna(test_data['CustomerLowQualityindicator'].mode()[0])

# %%
train_data['cdss_most_rcnt_prob']=train_data['cdss_most_rcnt_prob'].fillna(train_data['cdss_most_rcnt_prob'].mean())
test_data['cdss_most_rcnt_prob']=test_data['cdss_most_rcnt_prob'].fillna(test_data['cdss_most_rcnt_prob'].mean())
train_data['cust_max_credit_12m_amt']=train_data['cust_max_credit_12m_amt'].fillna(train_data['cust_max_credit_12m_amt'].mean())
test_data['cust_max_credit_12m_amt']=test_data['cust_max_credit_12m_amt'].fillna(test_data['cust_max_credit_12m_amt'].mean())
train_data['cust_max_remit_12m_amt']=train_data['cust_max_remit_12m_amt'].fillna(train_data['cust_max_remit_12m_amt'].mean())
test_data['cust_max_remit_12m_amt']=test_data['cust_max_remit_12m_amt'].fillna(test_data['cust_max_remit_12m_amt'].mean())
train_data['cbr_3_score']=train_data['cbr_3_score'].fillna(train_data['cbr_3_score'].mean())
test_data['cbr_3_score']=test_data['cbr_3_score'].fillna(test_data['cbr_3_score'].mean())

# %%
train_data['cnsumr_chrg_actv_cust_cnt']=train_data['cnsumr_chrg_actv_cust_cnt'].fillna(train_data['cnsumr_chrg_actv_cust_cnt'].mode()[0])
test_data['cnsumr_chrg_actv_cust_cnt']=test_data['cnsumr_chrg_actv_cust_cnt'].fillna(test_data['cnsumr_chrg_actv_cust_cnt'].mode()[0])
train_data['cnsumr_lend_actv_cust_cnt']=train_data['cnsumr_lend_actv_cust_cnt'].fillna(train_data['cnsumr_lend_actv_cust_cnt'].mode()[0])
test_data['cnsumr_lend_actv_cust_cnt']=test_data['cnsumr_lend_actv_cust_cnt'].fillna(test_data['cnsumr_lend_actv_cust_cnt'].mode()[0])

# %%
train_data['cnsumr_lend_tot_util_ratio']=train_data['cnsumr_lend_tot_util_ratio'].fillna(train_data['cnsumr_lend_tot_util_ratio'].mean())
test_data['cnsumr_lend_tot_util_ratio']=test_data['cnsumr_lend_tot_util_ratio'].fillna(test_data['cnsumr_lend_tot_util_ratio'].mean())
train_data['sow_revol_avg_paydown_pct']=train_data['sow_revol_avg_paydown_pct'].fillna(train_data['sow_revol_avg_paydown_pct'].mean())
test_data['sow_revol_avg_paydown_pct']=test_data['sow_revol_avg_paydown_pct'].fillna(test_data['sow_revol_avg_paydown_pct'].mean())
train_data['sow_tot_revol_cnt']=train_data['sow_tot_revol_cnt'].fillna(train_data['sow_tot_revol_cnt'].mean())
test_data['sow_tot_revol_cnt']=test_data['sow_tot_revol_cnt'].fillna(test_data['sow_tot_revol_cnt'].mean())
train_data['sow_tot_trans_cnt']=train_data['sow_tot_trans_cnt'].fillna(train_data['sow_tot_trans_cnt'].mean())
test_data['sow_tot_trans_cnt']=test_data['sow_tot_trans_cnt'].fillna(test_data['sow_tot_trans_cnt'].mean())

# %%
test_data.isnull().sum()
# Out:
# count_accts                    0
# cm_age                         0
# flag_top_ed_spender            0
# flag_cust_fee_paid_6m          0
# pre6m_cust_spend               0
# pre6m_cust_roc_cnt             0
# pre6m_cust_non_disc_cnt        0
# pre6m_cust_disc_cnt            0
# pre6m_cust_online_cnt          0
# pre6m_cust_travel_cnt          0
# pre6m_cust_retail_cnt          0
# pre6m_cust_myca_active         0
# pre6m_cust_mob_logins          0
# pre6m_total_mc_trs             0
# Cust_tenure                    0
# pre6m_spend_active_ind         0
# highly_utilized_ind            0
# min_pay_ind                    0
# paid_in_full_ind               0
# sum_total_line_amt             0
# direct_debit_ind               0
# referrals                      0
# spillover                      0
# self_accts                     0
# CustomerLowQualityindicator    0
# cdss_most_rcnt_prob            0
# cust_max_credit_12m_amt        0
# cust_max_remit_12m_amt         0
# ...

# %%
train_data.isnull().sum()
# Out:
# profitable_flag                0
# count_accts                    0
# cm_age                         0
# flag_top_ed_spender            0
# flag_cust_fee_paid_6m          0
# pre6m_cust_spend               0
# pre6m_cust_roc_cnt             0
# pre6m_cust_non_disc_cnt        0
# pre6m_cust_disc_cnt            0
# pre6m_cust_online_cnt          0
# pre6m_cust_travel_cnt          0
# pre6m_cust_retail_cnt          0
# pre6m_cust_myca_active         0
# pre6m_cust_mob_logins          0
# pre6m_total_mc_trs             0
# Cust_tenure                    0
# pre6m_spend_active_ind         0
# highly_utilized_ind            0
# min_pay_ind                    0
# paid_in_full_ind               0
# sum_total_line_amt             0
# direct_debit_ind               0
# referrals                      0
# spillover                      0
# self_accts                     0
# CustomerLowQualityindicator    0
# cdss_most_rcnt_prob            0
# cust_max_credit_12m_amt        0
# ...

# %%
df1 = train_data.dropna()
df1.head(20)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19596 entries, 0 to 19595
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   profitable_flag              19596 non-null  float64
#  1   count_accts                  19596 non-null  float64
#  2   cm_age                       19596 non-null  float64
#  3   flag_top_ed_spender          19596 non-null  float64
#  4   flag_cust_fee_paid_6m        19596 non-null  float64
#  5   pre6m_cust_spend             19596 non-null  float64
#  6   pre6m_cust_roc_cnt           19596 non-null  float64
#  7   pre6m_cust_non_disc_cnt      19596 non-null  float64
#  8   pre6m_cust_disc_cnt          19596 non-null  float64
#  9   pre6m_cust_online_cnt        19596 non-null  float64
#  10  pre6m_cust_travel_cnt        19596 non-null  float64
#  11  pre6m_cust_retail_cnt        19596 non-null  float64
# ...

# %%
print(df1.shape,test_data.shape,train_data.shape)
# Out:
# (19596, 39) (5000, 38) (19596, 39)

# %%
y = df1.iloc[:,0]
x= df1.iloc[:,1:]

# %%
x.shape, test_data.shape
# Out:
# ((19596, 38), (5000, 38))

# %%
# Finding most important features

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt

# %%
model = ExtraTreesClassifier()
model.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
u = model.fit(x,y)

# %%
print(model.feature_importances_)
# Out:
# [0.01159854 0.05089489 0.01164596 0.00935014 0.05461821 0.04485991
#  0.04494423 0.04608503 0.0460028  0.04815105 0.04468756 0.03832575
#  0.03848022 0.04633577 0.04238377 0.00219719 0.00781637 0.00249909
#  0.01491743 0.04452694 0.01570922 0.02562989 0.01015398 0.0019896
#  0.00114524 0.02377645 0.0449596  0.04402087 0.04571301 0.00785669
#  0.01223502 0.04195995 0.01542212 0.01554044 0.0262716  0.00972282
#  0.00719265 0.00038   ]

# %%
feature_imp  = pd.Series(model.feature_importances_,index= x.columns)
feature_imp.nlargest(20).plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
corrmat = df1.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(40,40))
g=sns.heatmap(df1[top_corr_features].corr(),annot=True)

# %%
#models

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import xgboost
from sklearn.ensemble import RandomForestClassifier

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
#decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
param_grid2 = {'max_leaf_nodes': list(range(2, 100)),'min_samples_split': [2, 3, 4]}

#Creating the classifier
model2 = DecisionTreeClassifier(random_state=2)

grid_search2 = GridSearchCV(model2, param_grid=param_grid2, cv=5, scoring='recall', verbose=4)
grid_search2.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 294 candidates, totalling 1470 fits
# [CV] max_leaf_nodes=2, min_samples_split=2 ...........................
# [CV]  max_leaf_nodes=2, min_samples_split=2, score=0.000, total=   0.0s
# [CV] max_leaf_nodes=2, min_samples_split=2 ...........................
# [CV]  max_leaf_nodes=2, min_samples_split=2, score=0.000, total=   0.0s
# [CV] max_leaf_nodes=2, min_samples_split=2 ...........................
# [CV]  max_leaf_nodes=2, min_samples_split=2, score=0.000, total=   0.0s
# [CV] max_leaf_nodes=2, min_samples_split=2 ...........................
# [CV]  max_leaf_nodes=2, min_samples_split=2, score=0.000, total=   0.0s
# [CV] max_leaf_nodes=2, min_samples_split=2 ...........................
# [CV]  max_leaf_nodes=2, min_samples_split=2, score=0.000, total=   0.0s
# [CV] max_leaf_nodes=2, min_samples_split=3 ...........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
print(grid_search2.best_score_)
print(grid_search2.best_params_)
# Out:
# 0.08616683470662541
# {'max_leaf_nodes': 99, 'min_samples_split': 2}

# %%
y_pred2 = grid_search2.predict(x_test)
print(accuracy_score(y_test,y_pred2))
# Out:
# 0.8122448979591836

# %%
pred_DTC = grid_search2.predict(test_data)

# %%
pred_DTC.shape
# Out:
# (5000,)

# %%
np.savetxt("solution_DTC.csv", pred_DTC, delimiter=",")

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
cm = confusion_matrix(y_pred2, y_test)
cm
# Out:
# array([[3145,  669],
#        [  67,   39]], dtype=int64)
